# %% [markdown]
# <a href="https://colab.research.google.com/github/avalenciacu/VALENCIA-ALEXIS-s-y-s/blob/main/certificados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Certificados de Kaggle**

# %% [markdown]
# ![AlexisAndresValencia - Python.png](data:image/png;base64,...)

# %% [markdown]
# ![AlexisAndresValencia - Intro to Programming.png](data:image/png;base64,...)
